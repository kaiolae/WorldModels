# %%
import os

path = os.getcwd()

print(path)
# Out:
# /itf-fi-ml/home/kaiolae/test_project/WorldModels/notebooks

# %%
import numpy as np
#obs_file = "../data/obs_data_doomrnn_0.npy"
#obs_file = "../data_small_episodes/obs_data_doomrnn_1.npy"
obs_file = "/scratch/users/kaiolae/training_data_folder_skiing/obs_data_Skiing-v0_0.npy"
actions_file = "/scratch/users/kaiolae/training_data_folder_skiing/action_data_Skiing-v0_0.npy"
#actions_file = "../data_small_episodes/action_data_doomrnn_1.npy"

obs = np.load(obs_file,allow_pickle=True)

# %%
#print(obs.shape)
vae_history = "../vae_model_64_dim/world_model_training_history.h5"
import pickle
content = "c"
with open(vae_history, 'rb') as pickle_file:
    content = pickle.load(pickle_file, encoding='latin1')

l2= {'loss2': [7678.717714853155, 7633.035384540659, 7627.476058840024, 7624.424802773667, 7622.77177038383, 7621.5966708978885, 7620.826163852572, 7620.23794887195, 7619.744027886173, 7619.320290429043, 7618.935311908609, 7618.620729014137, 7618.337509889653, 7618.080483773182, 7617.814063094774, 7618.3595077783975, 7617.434771479516, 7617.273197134453, 7617.150929299058, 7616.970980641193]}
content.append(l2)
print(content)

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import display, HTML


def plot_movie_mp4(image_array):
    dpi = 2.0
    xpixels, ypixels = image_array[0].shape[0], image_array[0].shape[1]
    fig = plt.figure(figsize=(ypixels/dpi, xpixels/dpi), dpi=dpi)
    #fig = plt.figure(figsize=(1,1), dpi=dpi)
    im = plt.figimage(image_array[0])

    def animate(i):
        im.set_array(image_array[i])
        return (im,)

    anim = animation.FuncAnimation(fig, animate, frames=len(image_array))
    
    video = anim.to_html5_video()
    html = display.HTML(video)
    display.display(html)
    plt.close() 
    #return anim
    #plt.show()
    #display(HTML(anim.to_html5_video()))
print ("DONE")
# Out:
# DONE

# %%
obs.shape
# Out:
# (10,)

# %%
# Enable interactive plot
#%matplotlib notebook
#anim=plot_movie_mp4(obs[0][2])
#print("Before flip: ", obs[0][3])
#flipped=np.flip(obs[0][2][:][:][0],2)
episode_done = False
obs_counter = 0
obs_skip = 100
while not episode_done:
    oneimg = obs[0][obs_counter]
    obs_counter+=obs_skip
    if obs_counter > len(obs[0]):
        episode_done=True
    inverted = 255-oneimg

    plt.imshow(inverted)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-b2ed90a5e937> in <module>
#       8 obs_skip = 100
#       9 while not episode_done:
# ---> 10     oneimg = obs[0][obs_counter]
#      11     obs_counter+=obs_skip
#      12     if obs_counter > len(obs[0]):
#
# IndexError: index 2100 is out of bounds for axis 0 with size 2100

# %%
actions = np.load(actions_file,allow_pickle = True)
print(actions)
# Out:
# [array([1, 1, 1, ..., 2, 2, 2]) array([2, 1, 1, ..., 1, 2, 2])
#  array([1, 1, 1, ..., 2, 2, 2]) array([0, 0, 1, ..., 1, 1, 1])
#  array([2, 2, 2, ..., 0, 0, 1]) array([0, 1, 1, ..., 2, 0, 0])
#  array([1, 1, 1, ..., 2, 2, 2]) array([1, 1, 1, ..., 1, 1, 1])
#  array([1, 2, 2, ..., 2, 1, 1]) array([0, 0, 2, ..., 0, 0, 1])]
